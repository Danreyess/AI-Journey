# %%
import os
import requests
from dotenv import load_dotenv
from openai import OpenAI  # pyright: ignore[reportUnusedImport]
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f'OpenAI API Key exists and begins {openai_api_key[:8]}')
else:
    print('OpenAI Key not set')
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
#Telling a joke
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for student on the journey to becoming an expert in LLM Engineering"}
]

# %%
client = OpenAI(api_key=openai_api_key)

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=tell_a_joke
)
# Out:
# ChatCompletion(id='chatcmpl-DUjo0FHcCejQkxcZP9OBH3lRg3gTg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Why did the language model break up with its partner?\n\nBecause it just couldn't handle the “extra context”!", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1776218288, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_f9565ce549', usage=CompletionUsage(completion_tokens=21, prompt_tokens=23, total_tokens=44, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the language model break up with its partner?
#
# Because it just couldn't handle the “extra context”!
